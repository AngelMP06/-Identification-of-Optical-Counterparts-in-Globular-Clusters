# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import json
import math

# %%
def create_dict_sources():
    M55_sources = {
        "CX1":  {"RA": "19h40m08.593s", "Decl": "-30d58m52.08s", "Xsoft": "60/74.3",  "Xmed": "102/123.5", "Xhard": "45/47.9"},
        "CX2":  {"RA": "19h39m57.877s", "Decl": "-30d56m11.67s", "Xsoft": "27/32.8",  "Xmed": "44/51.4",  "Xhard": "18/18.5"},
        "CX3":  {"RA": "19h40m04.720s", "Decl": "-30d56m47.09s", "Xsoft": "14/17.0",  "Xmed": "33/38.6",  "Xhard": "22/22.8"},
        "CX4":  {"RA": "19h40m09.192s", "Decl": "-30d56m58.54s", "Xsoft": "4/4.9",    "Xmed": "21/24.7",  "Xhard": "19/19.8"},
        "CX5":  {"RA": "19h40m08.846s", "Decl": "-30d56m20.34s", "Xsoft": "10/11.8",  "Xmed": "15/17.5",  "Xhard": "7/7.5"},
        "CX6":  {"RA": "19h39m53.108s", "Decl": "-31d00m14.99s", "Xsoft": "5/6.0",    "Xmed": "12/13.8",  "Xhard": "8/8.2"},
        "CX7":  {"RA": "19h39m51.190s", "Decl": "-30d59m01.01s", "Xsoft": "10/11.8",  "Xmed": "13/14.7",  "Xhard": "3/3.1"},
        "CX8":  {"RA": "19h40m03.279s", "Decl": "-30d59m05.61s", "Xsoft": "5/6.2",    "Xmed": "10/12.1",  "Xhard": "6/6.5"},
        "CX9":  {"RA": "19h39m54.920s", "Decl": "-30d57m18.01s", "Xsoft": "0/0.0",    "Xmed": "8/9.3",    "Xhard": "10/10.2"},
        "CX10": {"RA": "19h40m04.932s", "Decl": "-30d59m37.68s", "Xsoft": "3/3.7",    "Xmed": "9/10.9",   "Xhard": "6/6.5"},
        "CX11": {"RA": "19h40m00.235s", "Decl": "-30d57m39.85s", "Xsoft": "3/3.3",    "Xmed": "7/7.3",    "Xhard": "4/3.6"},
        "CX12": {"RA": "19h40m01.887s", "Decl": "-30d56m19.48s", "Xsoft": "2/2.4",    "Xmed": "5/5.9",    "Xhard": "4/4.2"},
        "CX13": {"RA": "19h39m58.668s", "Decl": "-30d59m22.01s", "Xsoft": "0/0.0",    "Xmed": "5/6.3",    "Xhard": "6/7.0"},
        "CX14": {"RA": "19h40m00.479s", "Decl": "-30d59m38.08s", "Xsoft": "0/0.0",    "Xmed": "5/5.4",    "Xhard": "5/5.1"},
        "CX15": {"RA": "19h39m59.793s", "Decl": "-30d55m26.12s", "Xsoft": "4/5.4",    "Xmed": "5/6.3",    "Xhard": "1/0.8"},
        "CX16": {"RA": "19h40m06.829s", "Decl": "-30d57m12.29s", "Xsoft": "5/6.4",    "Xmed": "5/5.9",    "Xhard": "0/0.0"},
        "CX17": {"RA": "19h40m08.214s", "Decl": "-30d57m15.47s", "Xsoft": "3/3.7",    "Xmed": "4/4.6",    "Xhard": "1/0.8"},
        "CX18": {"RA": "19h39m42.130s", "Decl": "-30d55m45.48s", "Xsoft": "71/101.4", "Xmed": "137/170.8","Xhard": "72/75.8"},
        "CX19": {"RA": "19h39m44.842s", "Decl": "-30d58m47.54s", "Xsoft": "5/6.4",    "Xmed": "11/12.8",  "Xhard": "6/6.0"},
        "CX20": {"RA": "19h39m45.876s", "Decl": "-30d57m40.03s", "Xsoft": "29/38.5",  "Xmed": "92/112.6", "Xhard": "78/82.9"},
        "CX21": {"RA": "19h39m45.989s", "Decl": "-31d01m31.65s", "Xsoft": "4/5.2",    "Xmed": "14/15.2",  "Xhard": "13/12.0"},
        "CX22": {"RA": "19h39m46.573s", "Decl": "-31d02m26.47s", "Xsoft": "33/44.2",  "Xmed": "65/77.3",  "Xhard": "34/33.9"},
        "CX23": {"RA": "19h39m47.994s", "Decl": "-30d55m24.12s", "Xsoft": "8/23.8",   "Xmed": "11/28.6",  "Xhard": "3/6.5"},
        "CX24": {"RA": "19h39m55.778s", "Decl": "-31d02m04.98s", "Xsoft": "207/264.9","Xmed": "304/368.1","Xhard": "106/112.5"},
        "CX25": {"RA": "19h39m57.005s", "Decl": "-31d03m07.82s", "Xsoft": "45/56.2",  "Xmed": "48/56.0",  "Xhard": "3/2.0"},
        "CX26": {"RA": "19h40m01.219s", "Decl": "-31d01m02.60s", "Xsoft": "0/0.0",    "Xmed": "3/3.0",    "Xhard": "7/7.1"},
        "CX27": {"RA": "19h40m03.284s", "Decl": "-31d01m52.73s", "Xsoft": "0/0.0",    "Xmed": "8/9.4",    "Xhard": "9/8.8"},
        "CX28": {"RA": "19h40m03.475s", "Decl": "-31d02m42.40s", "Xsoft": "25/30.0",  "Xmed": "37/42.7",  "Xhard": "13/12.6"},
        "CX29": {"RA": "19h40m13.402s", "Decl": "-30d59m45.22s", "Xsoft": "9/11.0",   "Xmed": "11/13.1",  "Xhard": "2/2.2"},
        "CX30": {"RA": "19h40m16.842s", "Decl": "-30d57m41.89s", "Xsoft": "4/5.5",    "Xmed": "10/12.3",  "Xhard": "6/6.0"},
        "CX31": {"RA": "19h40m18.981s", "Decl": "-31d00m13.35s", "Xsoft": "2/2.2",    "Xmed": "12/14.5",  "Xhard": "12/12.1"}
    }
    sources_fx = {
        "CX1":  {"fx_0_5_2_5": 1.2e-14, "fx_2_5_6_0": 1.4e-14},
        "CX2":  {"fx_0_5_2_5": 5.0e-15, "fx_2_5_6_0": 5.8e-15},
        "CX3":  {"fx_0_5_2_5": 3.4e-15, "fx_2_5_6_0": 7.9e-15},
        "CX4":  {"fx_0_5_2_5": 1.9e-15, "fx_2_5_6_0": 7.2e-15},
        "CX5":  {"fx_0_5_2_5": 1.9e-15, "fx_2_5_6_0": 2.1e-15},
        "CX6":  {"fx_0_5_2_5": 1.3e-15, "fx_2_5_6_0": 2.3e-15},
        "CX7":  {"fx_0_5_2_5": 1.7e-15, "fx_2_5_6_0": 1.1e-15},
        "CX8":  {"fx_0_5_2_5": 1.2e-15, "fx_2_5_6_0": 1.6e-15},
        "CX9":  {"fx_0_5_2_5": 6.1e-16, "fx_2_5_6_0": 3.6e-15},
        "CX10": {"fx_0_5_2_5": 9.2e-16, "fx_2_5_6_0": 1.7e-15},
        "CX11": {"fx_0_5_2_5": 8.1e-16, "fx_2_5_6_0": 6.4e-16},
        "CX12": {"fx_0_5_2_5": 5.8e-16, "fx_2_5_6_0": 1.2e-15},
        "CX13": {"fx_0_5_2_5": 4.8e-16, "fx_2_5_6_0": 2.4e-15},
        "CX14": {"fx_0_5_2_5": 4.3e-16, "fx_2_5_6_0": 1.4e-15},
        "CX15": {"fx_0_5_2_5": 6.4e-16, "fx_2_5_6_0": 5.8e-16},
        "CX16": {"fx_0_5_2_5": 7.6e-16, "fx_2_5_6_0": 2.0e-17},
        "CX17": {"fx_0_5_2_5": 5.7e-16, "fx_2_5_6_0": 6.9e-16},
        "CX18": {"fx_0_5_2_5": 1.8e-14, "fx_2_5_6_0": 2.0e-14},
        "CX19": {"fx_0_5_2_5": 1.2e-15, "fx_2_5_6_0": 2.0e-15},
        "CX20": {"fx_0_5_2_5": 9.7e-15, "fx_2_5_6_0": 2.9e-14},
        "CX21": {"fx_0_5_2_5": 1.5e-15, "fx_2_5_6_0": 4.7e-15},
        "CX22": {"fx_0_5_2_5": 8.1e-15, "fx_2_5_6_0": 1.2e-14},
        "CX23": {"fx_0_5_2_5": 3.5e-15, "fx_2_5_6_0": 1.2e-15},
        "CX24": {"fx_0_5_2_5": 3.9e-14, "fx_2_5_6_0": 2.6e-14},
        "CX25": {"fx_0_5_2_5": 7.1e-16, "fx_2_5_6_0": 4.8e-16},
        "CX26": {"fx_0_5_2_5": 6.9e-16, "fx_2_5_6_0": 3.9e-15},
        "CX27": {"fx_0_5_2_5": 6.4e-16, "fx_2_5_6_0": 3.1e-15},
        "CX28": {"fx_0_5_2_5": 4.7e-15, "fx_2_5_6_0": 4.2e-15},
        "CX29": {"fx_0_5_2_5": 1.6e-15, "fx_2_5_6_0": 7.7e-16},
        "CX30": {"fx_0_5_2_5": 1.0e-15, "fx_2_5_6_0": 3.0e-15},
        "CX31": {"fx_0_5_2_5": 1.3e-15, "fx_2_5_6_0": 5.0e-15}
    }
    
    df1 = pd.DataFrame(M55_sources).transpose()
    df2 = pd.DataFrame(sources_fx).transpose()
    df_unido = df1.join(df2,how = 'right')
    df_unido.rename(columns = {'fx_0_5_2_5': 'Fx_0.5-2.5', 'fx_2_5_6_0': 'Fx_2.5-6.0'}, inplace = True)
    dict = df_unido.to_dict()
    
    with open("C:/Users/HP/Desktop/Curso de Python/Workspace/miweb/Astronomía/sources.txt", "w") as f:
        json.dump(dict, f, indent=4)
    
#create_dict_sources()
#with open("C:/Users/HP/Desktop/Curso de Python/Workspace/miweb/Astronomía/sources.txt", "r") as f:
#    sources_dict = json.load(f)
#pd.DataFrame(sources_dict)

# %%
Mag_min = -100  # 0
Mag_max = 100   # 35
RMS_max = 1     # 0.1 #No quiero que aparezcan varias estrellas dentro del circulo, pues si eso sucede de todas formas no será posible dar un valor correcto
Fit_max = 1.5   # También puede ser 0.6, pero en en los filtros 606 y 814 no se pueden usar valores tan estrictos, pues se eliminarían demasiados puntos
Sharp_min = -2  # -0.25
Sharp_max = 2   # 0.25

# %%
path_optical = 'C:/Users/HP/Desktop/Curso de Python/Workspace/miweb/Astronomía/NGC6809.txt'
optical_data = pd.read_csv(
    path_optical,
    sep=r"\s+",      # split by any amount of whitespace
    header=None      # because there are no column names
)
optical_data.columns = [
    "X", "Y",
    "275_Mag", "275_RMS", "275_Fit", "275_Sharp", "275_exp_found", "275_exp_well",
    "336_Mag", "336_RMS", "336_Fit", "336_Sharp", "336_exp_found", "336_exp_well",
    "438_Mag", "438_RMS", "438_Fit", "438_Sharp", "438_exp_found", "438_exp_well",
    "606_Mag", "606_RMS", "606_Fit", "606_Sharp", "606_exp_found", "606_exp_well",
    "814_Mag", "814_RMS", "814_Fit", "814_Sharp", "814_exp_found", "814_exp_well",
    "Cluster_Membership",
    "RA", "Decl",
    "Id",
    "Iteration_found"
]
optical_data["Visible"] = (optical_data["438_Mag"]+optical_data["606_Mag"])/2
optical_data["Mv"] = optical_data["Visible"]-5*(math.log(5400,10)-1)

bands = ["275", "336", "438", "606", "814"]
mask = np.ones(len(optical_data), dtype=bool)
for b in bands:
    mask &= optical_data[f"{b}_Mag"].between(Mag_min, Mag_max)
    mask &= optical_data[f"{b}_RMS"] < RMS_max
    mask &= optical_data[f"{b}_Fit"] < Fit_max
    mask &= optical_data[f"{b}_Sharp"].between(Sharp_min, Sharp_max)
optical_data_filtered = optical_data[mask]
optical_data_filtered.reset_index(inplace = True)

optical_data_filtered
#optical_data_filtered.to_csv('C:/Users/HP/Desktop/Curso de Python/Workspace/miweb/Astronomía/NGC6809_optical.csv', index = False)
# Out:
#        index          X          Y  275_Mag  275_RMS  275_Fit  275_Sharp  \
# 0         44  5200.7725  2476.1838  18.4874   0.1510   0.9999    -0.0278
# 1         45  5220.7598  2478.8713  18.2868   0.1273   0.9935    -0.0435
# 2         51  5211.3027  2499.4172  18.6973   0.1226   0.9987    -0.0064
# 3         55  5305.9165  2516.5413  18.5293   0.0205   0.9952     0.0081
# 4         62  5180.4756  2551.7551  19.5017   0.0599   0.9928     0.0415
# ...      ...        ...        ...      ...      ...      ...        ...
# 12700  45687  5069.7119  7757.6245  20.9273   0.0899   0.9996     0.0046
# 12701  45688  5076.8477  7753.7788  23.0908   0.0397   0.9972     0.0389
# 12702  45714  5483.0840  7700.8340  25.0950   0.7877   0.7675    -0.4441
# 12703  45715  5492.9966  7712.1431  26.8470   0.4574   0.6135    -0.5166
# 12704  45719  5514.7529  7729.0205  23.6081   0.1083   0.9950    -1.0000
#
#        275_exp_found  275_exp_well  336_Mag  ...  814_Sharp  814_exp_found  \
# ...

# %%
from matplotlib import colors
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from scipy.signal import savgol_filter


NGC = "NGC6809"
gráfico_comp = 2
min_count = 2
min_step = 2
path_optical = f'C:/Users/HP/Desktop/Curso de Python/Workspace/miweb/Astronomía/{NGC}_optical.csv'


if gráfico_comp == 0: #F275W-F336W
    Color1 = "275"
    Color2 = "336"
elif gráfico_comp == 1: #F438W-F606W
    Color1 = "438"
    Color2 = "606"
elif gráfico_comp == 2: #F606W-F814W
    Color1 = "606"
    Color2 = "814"

optical_data = pd.read_csv(path_optical)

#Cargamos los datos
S_Color1 = optical_data[Color1+"_Mag"]
S_Color2 = optical_data[Color2+"_Mag"]
n_Data = len(S_Color1)
    

datos=np.zeros([n_Data,2])

S_dif = S_Color1 - S_Color2

# %%
S_Color2.max()
# Out:
# 25.5663
